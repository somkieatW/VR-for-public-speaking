# %%
# !pip install pyaudio
# !pip install gTTS
# !pip install speechrecognition
# Out:
# Requirement already satisfied: pyaudio in c:\users\paeku\anaconda2\lib\site-packages (0.2.11)
# Requirement already satisfied: gTTS in c:\users\paeku\anaconda2\lib\site-packages (2.0.3)
# Requirement already satisfied: gtts-token in c:\users\paeku\anaconda2\lib\site-packages (from gTTS) (1.1.3)
# Requirement already satisfied: six in c:\users\paeku\anaconda2\lib\site-packages (from gTTS) (1.12.0)
# Requirement already satisfied: requests in c:\users\paeku\anaconda2\lib\site-packages (from gTTS) (2.21.0)
# Requirement already satisfied: bs4 in c:\users\paeku\anaconda2\lib\site-packages (from gTTS) (0.0.1)
# Requirement already satisfied: click in c:\users\paeku\anaconda2\lib\site-packages (from gTTS) (7.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\paeku\anaconda2\lib\site-packages (from requests->gTTS) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paeku\anaconda2\lib\site-packages (from requests->gTTS) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\paeku\anaconda2\lib\site-packages (from requests->gTTS) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\paeku\anaconda2\lib\site-packages (from requests->gTTS) (3.0.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\paeku\anaconda2\lib\site-packages (from bs4->gTTS) (4.6.3)
# Collecting speechrecognition
#   Using cached https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl
# Installing collected packages: speechrecognition
# Successfully installed speechrecognition-3.8.1

# %%
from gtts import gTTS
import os
tts = gTTS(text='Hello guy. I am Brinicle.', lang='en')
tts.save("hello.mp3")
os.system("mpg321 hello.mp3")
# Out:
# 1

# %%
import speech_recognition as sr
from time import ctime
import pyaudio
import time
import os
from gtts import gTTS

# %%
def speak(audioString):
    print(audioString)
    tts = gTTS(text=audioString, lang='en')
    tts.save("audio.mp3")
    os.system("mpg321 audio.mp3")

# %%
def recordAudio():
    # Record Audio
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Say something!")
        audio = r.listen(source)
    data = ""
    try:
        # Uses the default API key
        # To use another API key: `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
        data = r.recognize_google(audio)
        print("You said: " + data)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")     
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
    
    return data

# %%
def jarvis(data):
    if "how are you" in data:
        speak("I am fine")
 
    if "what time is it" in data:
        speak(ctime())
 
    if "where is" in data:
        data = data.split(" ")
        location = data[2]
        speak("Hold on Frank, I will show you where " + location + " is.")
        os.system("chromium-browser https://www.google.nl/maps/place/" + location + "/&amp;")

# %%
time.sleep(2)
speak("Hi Frank, what can I do for you?")
while 1:
    data = recordAudio()
    jarvis(data)
# Out:
# Hi Frank, what can I do for you?
# Say something!
# You said: switching
# Say something!
# You said: 15 switch
# Say something!
# You said: so we chat
# Say something!
# You said: sourcing
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: salvation
# Say something!
# You said: when when
# Say something!
# You said: when
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: went went
# Say something!
# You said: gone is gone
# Say something!
# You said: is it's gone
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: understand audio
# Say something!
# You said: understanding understand
# Say something!
# You said: dispatch
# Say something!
# You said: no new
# Say something!
# You said: no no
# Say something!
# You said: I know
# Say something!
# You said: I knew it
# Say something!
# You said: I got it
# Say something!
# You said: Henrico
# Say something!
# You said: can we go
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: let's go
# Say something!
# You said: let me go
# Say something!
# You said: tiger
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: thank you very much
# Say something!
# You said: o que Risco
# Say something!
# You said: Ocala School
# Say something!
# You said: okay let's go
# Say something!
# You said: shut up
# Say something!
# You said: Tio Rico
# Say something!
# You said: here we go
# Say something!
# You said: shooting star
# Say something!
# You said: shoot
# Say something!
# You said: shut
# Say something!
# You said: Shopkin
# Say something!
# You said: cut it out
# Say something!
# You said: say something
# Say something!
# You said: same anything
# Say something!
# You said: say something
# Say something!
# You said: please say something
# Say something!
# You said: anything else
# Say something!
# You said: wow
# Say something!
# You said: is cool
# Say something!
# You said: it's cool
# Say something!
# You said: how you there
# Say something!
# You said: are you there
# Say something!
# You said: here I am
# Say something!
# You said: Do You Want to Build a Snowman
# Say something!
# You said: Pokemon
# Say something!
# You said: trading card
# Say something!
# You said: Nintendo switch
# Say something!
# You said: PlayStation 4
# Say something!
# You said: Monster Hunter world
# Say something!
# You said: Monster Hunter world
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: black desserts
# Say something!
# You said: disa
# Say something!
# You said: this sucks
# Say something!
# You said: Best Buy
# Say something!
# You said: desert design
# Say something!
# You said: dessert
# Say something!
# You said: deserved
# Say something!
# You said: design
# Say something!
# You said: light
# Say something!
# You said: light
# Say something!
# You said: light
# Say something!
# You said: all right
# Say something!
# You said: light
# Say something!
# You said: life
# Say something!
# You said: life
# Say something!
# You said: light up diligent
# Say something!
# You said: light up Legion
# Say something!
# You said: life of leisure
# Say something!
# You said: growing up
# Say something!
# You said: lice
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: oh
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: Anaconda
# Say something!
# You said: set up
# Say something!
# You said: for men
# Say something!
# You said: format
# Say something!
# You said: Atari
# Say something!
# You said: Factory
# Say something!
# You said: Swift station
# Say something!
# You said: what station
# Say something!
# You said: work citation
# Say something!
# You said: what station
# Say something!
# You said: work probation
# Say something!
# You said: training station
# Say something!
# You said: Unity
# Say something!
# You said: open house
# Say something!
# You said: opaline house
# Say something!
# You said: light house
# Say something!
# You said: open house
# Say something!
# You said: open
# Say something!
# You said: fuk up
# Say something!
# You said: installer
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: window
# Say something!
# You said: McCutcheon
# Say something!
# You said: how old is
# Say something!
# You said: wow
# Say something!
# You said: piss pronoun
# Say something!
# You said: blue
# Say something!
# You said: book
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: I live to lead a book
# Say something!
# You said: I live in Toledo
# Say something!
# You said: Eliza Brook
# Say something!
# You said: reading book
# Say something!
# You said: leet
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: please
# Say something!
# You said: leap
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: look up
# Say something!
# You said: set up
# Say something!
# You said: cooktop
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# You said: stop
# Say something!
# You said: yes sir
# Say something!
# You said: alright
# Say something!
# You said: bluetooth app
# Say something!
# You said: Logitech
# Say something!
# You said: look stickmount
# Say something!
# Google Speech Recognition could not understand audio
# Say something!
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-15-20a900351948> in <module>()
#       2 speak("Hi Frank, what can I do for you?")
#       3 while 1:
# ----> 4     data = recordAudio()
#       5     jarvis(data)
#
# <ipython-input-10-3e3ec757447b> in recordAudio()
#       4     with sr.Microphone() as source:
#       5         print("Say something!")
# ----> 6         audio = r.listen(source)
#       7     data = ""
#       8     try:
#
# C:\Users\paeku\Anaconda2\lib\site-packages\speech_recognition\__init__.pyc in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     650                     break
#     651
# --> 652                 buffer = source.stream.read(source.CHUNK)
#     653                 if len(buffer) == 0: break  # reached end of the stream
#     654                 frames.append(buffer)
#
# C:\Users\paeku\Anaconda2\lib\site-packages\speech_recognition\__init__.pyc in read(self, size)
#     159
#     160         def read(self, size):
# --> 161             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     162
#     163         def close(self):
#
# C:\Users\paeku\Anaconda2\lib\site-packages\pyaudio.pyc in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:
